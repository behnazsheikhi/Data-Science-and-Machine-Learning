# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/Behnaz/Documents/Data-Science-and-Machine-Learning/Python_Courses/TensorFlow_FILES/DATA/kc_house_data.csv')

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# # Check The Missing Value

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# C:\Users\Behnaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\Behnaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x=df['price'],y=df['sqft_living'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x=df['bedrooms'],y=df['price'],data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='lat',y='long',data=df,hue='price')
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
len(df)*0.01
# Out:
# 215.97

# %%
df_new=df.sort_values('price',ascending=False).iloc[216:]

# %%
df_new.sort_values('price',ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(x='long',y='lat',data=df_new,hue='price',palette='RdYlGn')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.head
# Out:
# <bound method NDFrame.head of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %%
df_new.head()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6329       8510     2.0           0     1  ...     10        3610
# 12271     23373     3.0           0     1  ...     11        5050
# 9166      12566     1.0           1     4  ...      8        1940
# 12565     31353     2.0           0     0  ...     12        4430
# 1150       7898     1.0           1     4  ...      8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df_new.shape
# Out:
# (21381, 21)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21381 entries, 6329 to 15279
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21381 non-null  int64
#  1   date           21381 non-null  object
#  2   price          21381 non-null  float64
#  3   bedrooms       21381 non-null  int64
#  4   bathrooms      21381 non-null  float64
#  5   sqft_living    21381 non-null  int64
#  6   sqft_lot       21381 non-null  int64
#  7   floors         21381 non-null  float64
#  8   waterfront     21381 non-null  int64
#  9   view           21381 non-null  int64
#  10  condition      21381 non-null  int64
#  11  grade          21381 non-null  int64
#  12  sqft_above     21381 non-null  int64
#  13  sqft_basement  21381 non-null  int64
#  14  yr_built       21381 non-null  int64
#  15  yr_renovated   21381 non-null  int64
#  16  zipcode        21381 non-null  int64
# ...

# %% [markdown]
# # Drop unwanted columns

# %%
df_new.drop('id',axis=1,inplace=True)

# %% [markdown]
# # Change the format of the date from string to date

# %%
df_new['date']=pd.to_datetime(df_new['date'])

# %%
df_new['date']
# Out:
# 6329    2014-06-02
# 12271   2014-10-15
# 9166    2015-02-13
# 12565   2015-04-22
# 1150    2015-04-21
#            ...
# 2139    2014-05-08
# 8267    2014-11-05
# 16184   2015-03-24
# 465     2014-05-23
# 15279   2014-05-06
# Name: date, Length: 21381, dtype: datetime64[ns]

# %%
df_new['date'].iloc[1].year
# Out:
# 2014

# %%
df_new['year']=df_new['date'].apply(lambda date: date.year)
df_new['month']=df_new['date'].apply(lambda date: date.month)

# %%
df_new['month']
# Out:
# 6329      6
# 12271    10
# 9166      2
# 12565     4
# 1150      4
#          ..
# 2139      5
# 8267     11
# 16184     3
# 465       5
# 15279     5
# Name: month, Length: 21381, dtype: int64

# %%
df_new.head()
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321 2014-06-02  1970000.0         4       3.50         4370
# 12271  1923000260 2014-10-15  1960000.0         5       4.50         6200
# 9166   3124059023 2015-02-13  1960000.0         3       1.75         3330
# 12565  2806300065 2015-04-22  1960000.0         4       4.00         4430
# 1150   4055701200 2015-04-21  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 6329       8510     2.0           0     1  ...            760      2003
# 12271     23373     3.0           0     1  ...           1150      1988
# 9166      12566     1.0           1     4  ...           1390      1960
# 12565     31353     2.0           0     0  ...              0      1998
# 1150       7898     1.0           1     4  ...           1560      1963
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
sns.boxplot(x='month',y='price',data=df_new)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df_new.groupby('month').mean()['price'].sort_values()
# Out:
# month
# 2     493269.607114
# 11    499781.279770
# 12    503406.086598
# 1     504981.466942
# 9     507255.324601
# 8     511327.311946
# 10    519494.580247
# 5     522940.482570
# 3     523761.809164
# 7     526694.006390
# 6     533429.116009
# 4     541452.515165
# Name: price, dtype: float64

# %%
df_new.groupby('year').mean()['price'].sort_values()
# Out:
# year
# 2014    517282.707004
# 2015    520642.628712
# Name: price, dtype: float64

# %%
df_new.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df_new.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_new.drop('date',axis=1,inplace=True)

# %%
df_new.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 6329            0     1          3     10  ...            760      2003
# 12271           0     1          4     11  ...           1150      1988
# 9166            1     4          4      8  ...           1390      1960
# 12565           0     0          3     12  ...              0      1998
# 1150            1     4          4      8  ...           1560      1963
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df_new.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df_new.drop('zipcode',axis=1,inplace=True)

# %% [markdown]
# # These two features can be considered as categorical features
# because they can be considered as renovated or not/ has basement or not

# %%
df_new['yr_renovated'].value_counts()
# Out:
# 0       20499
# 2014       91
# 2013       36
# 2000       34
# 2005       34
#         ...
# 1934        1
# 1954        1
# 1948        1
# 1959        1
# 1951        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df_new.groupby('yr_renovated')['price'].mean().plot()
# Out:
# <AxesSubplot:xlabel='yr_renovated'>

# %%
df_new['sqft_basement'].value_counts()
# Out:
# 0       13052
# 600       219
# 500       214
# 700       214
# 800       205
#         ...
# 1852        1
# 1890        1
# 1481        1
# 1284        1
# 652         1
# Name: sqft_basement, Length: 292, dtype: int64

# %%
df_new.groupby('sqft_basement')['price'].mean().plot()
# Out:
# <AxesSubplot:xlabel='sqft_basement'>

# %% [markdown]
# # Test and Train Split

# %%
X=df_new.drop('price',axis=1).values
y=df_new['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
X_train.shape
# Out:
# (14966, 19)

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
         batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 117/117 [==============================] - 1s 4ms/step - loss: 346867138560.0000 - val_loss: 356814159872.0000
# Epoch 2/400
# 117/117 [==============================] - 0s 2ms/step - loss: 345300434944.0000 - val_loss: 351199199232.0000
# Epoch 3/400
# 117/117 [==============================] - 0s 2ms/step - loss: 323022127104.0000 - val_loss: 299221778432.0000
# Epoch 4/400
# 117/117 [==============================] - 0s 2ms/step - loss: 222788485120.0000 - val_loss: 146764627968.0000
# Epoch 5/400
# 117/117 [==============================] - 0s 2ms/step - loss: 85124079616.0000 - val_loss: 57721745408.0000
# Epoch 6/400
# 117/117 [==============================] - 0s 2ms/step - loss: 54231113728.0000 - val_loss: 54448529408.0000
# Epoch 7/400
# 117/117 [==============================] - 0s 2ms/step - loss: 53036478464.0000 - val_loss: 53419040768.0000
# Epoch 8/400
# ...
